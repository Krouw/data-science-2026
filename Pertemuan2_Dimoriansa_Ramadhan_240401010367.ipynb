# %% [markdown]
# <a href="https://colab.research.google.com/github/Krouw/data-science-2026/blob/main/Pertemuan2_Dimoriansa_Ramadhan_240401010367.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

URL = "https://raw.github.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(URL)

df[['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Q1: Muat Dataset Titanic

import pandas as pd
import numpy as np

URL = "https://raw.github.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(URL)
print(df.shape, df.columns.tolist())

#A1: dataset Titanic memiliki 891 baris dan 12 kolom.
# Out:
# (891, 12) ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %%
#Q2: Kolom mana yang memiliki nilai kosong (missing) ?

print(df.isnull().sum())

#A2: ada 3 kolom yang memiliki nilai missing, yaitu age, cabin dan embarked.
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Q3: Berapa persen penumpang yang selamat (Survived=1) ?

selamat = df[df['Survived']==1]
survival_rate = len(selamat) / len(df)
({
    "Total Penumpang": [len(df)],
    "Jumlah Selamat": [df['Survived'].sum()],
    "Persentase Selamat (%)": [survival_rate * 100]
})

#A3: Penumpang yang berhasil selamat ialah 38.4% (38.38383838383838).
# Out:
# {'Total Penumpang': [891],
#  'Jumlah Selamat': [np.int64(342)],
#  'Persentase Selamat (%)': [38.38383838383838]}

# %%
#Q4: Rata-rata usia penumpang wanita kelas 1 yang selamat?

wanita_kelas1_selamat = df[
    (df['Sex'] == 'female') &
    (df['Pclass'] == 1) &
    (df['Survived'] == 1)
]
({
    "Jumlah Penumpang": [len(wanita_kelas1_selamat)],
    "Rata-rata Usia": [wanita_kelas1_selamat['Age'].mean()]
})

#Q4: Rata-rata usia penumpang wanita kelas 1 yang selamat ialah 35 tahun.
# Out:
# {'Jumlah Penumpang': [91], 'Rata-rata Usia': [np.float64(34.9390243902439)]}

# %%
#Q5: Kelas penumpang mana yang tingkat keselamatan tertinggi ?

survival_per_kelas = df.groupby('Pclass')['Survived'].mean()

hasil = survival_per_kelas.reset_index()
hasil.columns = ["Kelas", "Rata-rata"]
print(hasil)

#Q6: Tingkat keselamatan tertinggi pada kelas penumpang ialah kelas 1.
# Out:
#    Kelas  Rata-rata
# 0      1   0.629630
# 1      2   0.472826
# 2      3   0.242363

# %%
#Q6: Tampilkan hasil groupby('Pclass')['Survived'].mean()

df.groupby('Pclass')['Age'].mean()

#Q6: Berikut hasil outputnya.
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %% [markdown]
# Tugas ini dikerjakan menggunakan panduan dari PPT yang telah diberikan oleh bapak syahid.
#
# Terima kasih~
#
# ![image.png](data:image/png;base64,...)
